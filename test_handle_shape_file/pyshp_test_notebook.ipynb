# %%
import shapefile

# %%
sf = shapefile.Reader('/Users/warn/Desktop/cb_2016_us_state_20m/cb_2016_us_state_20m')
# Out:
# ---------------------------------------------------------------------------
# ShapefileException                        Traceback (most recent call last)
# <ipython-input-16-1327e56e5267> in <module>()
# ----> 1 sf = shapefile.Reader('/Users/warn/Desktop/cb_2016_us_state_20m')
#
# /usr/local/lib/python3.6/site-packages/shapefile.py in __init__(self, *args, **kwargs)
#     234         if len(args) > 0:
#     235             if is_string(args[0]):
# --> 236                 self.load(args[0])
#     237                 return
#     238         if "shp" in kwargs.keys():
#
# /usr/local/lib/python3.6/site-packages/shapefile.py in load(self, shapefile)
#     276                 pass
#     277             if not (self.shp and self.dbf):
# --> 278                 raise ShapefileException("Unable to open %s.dbf or %s.shp." % (shapeName, shapeName) )
#     279         if self.shp:
#     280             self.__shpHeader()
#
# ...

# %%
shapes = sf.shapes()

# %%
shapes[0].points
# Out:
# [(-68.92401, 43.885407),
#  (-68.87478399999999, 43.904714999999996),
#  (-68.849009, 43.849841),
#  (-68.888483, 43.803781),
#  (-68.944433, 43.835325999999995),
#  (-68.92401, 43.885407),
#  (-71.083924, 45.305451),
#  (-71.03820999999999, 45.311921999999996),
#  (-71.012757, 45.34476),
#  (-70.949365, 45.331536),
#  (-70.912111, 45.296197),
#  (-70.892822, 45.239171999999996),
#  (-70.84443, 45.234513),
#  (-70.8340195374401, 45.2717944023968),
#  (-70.82979, 45.286941),
#  (-70.808613, 45.311606),
#  (-70.819471, 45.341435),
#  (-70.80624399999999, 45.376557999999996),
#  (-70.82561199999999, 45.400304999999996),
#  (-70.781471, 45.431159),
#  (-70.755567, 45.428360999999995),
#  (-70.729972, 45.399359),
#  (-70.677995, 45.394362),
#  (-70.634661, 45.383607999999995),
#  (-70.635498, 45.427817),
#  (-70.674903, 45.452399),
#  (-70.723396, 45.510394),
#  (-70.688214, 45.563981),
#  (-70.64957799999999, 45.598147),
#  (-70.591275, 45.630551),
# ...

# %%
dir(shapes[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bbox',
#  'parts',
#  'points',
#  'shapeType']

# %%
print(shapes[0])

# %%
dir(sf)
# Out:
# ['_Reader__dbfHdrLength',
#  '_Reader__dbfHeader',
#  '_Reader__getFileObj',
#  '_Reader__recStruct',
#  '_Reader__record',
#  '_Reader__recordFmt',
#  '_Reader__recordLength',
#  '_Reader__restrictIndex',
#  '_Reader__shape',
#  '_Reader__shapeIndex',
#  '_Reader__shpHeader',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_offsets',
#  'bbox',
#  'dbf',
#  'elevation',
#  'fields',
#  'iterRecords',
#  'iterShapeRecords',
#  'iterShapes',
#  'load',
#  'measure',
#  'numRecords',
#  'record',
#  'records',
#  'shape',
#  'shapeName',
#  'shapeRecord',
#  'shapeRecords',
#  'shapeType',
#  'shapes',
#  'shp',
# ...

# %%
sf.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['STATEFP', 'C', 2, 0],
#  ['STATENS', 'C', 8, 0],
#  ['AFFGEOID', 'C', 11, 0],
#  ['GEOID', 'C', 2, 0],
#  ['STUSPS', 'C', 2, 0],
#  ['NAME', 'C', 100, 0],
#  ['LSAD', 'C', 2, 0],
#  ['ALAND', 'N', 14, 0],
#  ['AWATER', 'N', 14, 0]]

# %%
dir(sf.shapeRecords()[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'record',
#  'shape']

# %%
dir(sf.shapeRecords()[0].shape)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bbox',
#  'parts',
#  'points',
#  'shapeType']

# %%
record = sf.shapeRecords()[0]

# %%
record.shape.points
# Out:
# [(-68.92401, 43.885407),
#  (-68.87478399999999, 43.904714999999996),
#  (-68.849009, 43.849841),
#  (-68.888483, 43.803781),
#  (-68.944433, 43.835325999999995),
#  (-68.92401, 43.885407),
#  (-71.083924, 45.305451),
#  (-71.03820999999999, 45.311921999999996),
#  (-71.012757, 45.34476),
#  (-70.949365, 45.331536),
#  (-70.912111, 45.296197),
#  (-70.892822, 45.239171999999996),
#  (-70.84443, 45.234513),
#  (-70.8340195374401, 45.2717944023968),
#  (-70.82979, 45.286941),
#  (-70.808613, 45.311606),
#  (-70.819471, 45.341435),
#  (-70.80624399999999, 45.376557999999996),
#  (-70.82561199999999, 45.400304999999996),
#  (-70.781471, 45.431159),
#  (-70.755567, 45.428360999999995),
#  (-70.729972, 45.399359),
#  (-70.677995, 45.394362),
#  (-70.634661, 45.383607999999995),
#  (-70.635498, 45.427817),
#  (-70.674903, 45.452399),
#  (-70.723396, 45.510394),
#  (-70.688214, 45.563981),
#  (-70.64957799999999, 45.598147),
#  (-70.591275, 45.630551),
# ...

# %%
sf.shapeRecords()[3].record
# Out:
# ['05',
#  '00068085',
#  '0400000US05',
#  '05',
#  'AR',
#  'Arkansas',
#  '00',
#  134771517596,
#  2960191698]

# %%
for rec in sf.shapeRecords():
    state_name = '_'.join(rec.record[5].split(' ')).upper()
    print('{} = "{}"'.format(state_name, rec.record[5]))
# Out:
# MAINE = "Maine"
# HAWAII = "Hawaii"
# ARIZONA = "Arizona"
# ARKANSAS = "Arkansas"
# DELAWARE = "Delaware"
# GEORGIA = "Georgia"
# MINNESOTA = "Minnesota"
# ALASKA = "Alaska"
# CALIFORNIA = "California"
# DISTRICT_OF_COLUMBIA = "District of Columbia"
# FLORIDA = "Florida"
# IDAHO = "Idaho"
# ILLINOIS = "Illinois"
# IOWA = "Iowa"
# KENTUCKY = "Kentucky"
# LOUISIANA = "Louisiana"
# MARYLAND = "Maryland"
# MICHIGAN = "Michigan"
# MISSOURI = "Missouri"
# MONTANA = "Montana"
# NEW_YORK = "New York"
# OREGON = "Oregon"
# TENNESSEE = "Tennessee"
# TEXAS = "Texas"
# VIRGINIA = "Virginia"
# WISCONSIN = "Wisconsin"
# SOUTH_DAKOTA = "South Dakota"
# UTAH = "Utah"
# INDIANA = "Indiana"
# MASSACHUSETTS = "Massachusetts"
# MISSISSIPPI = "Mississippi"
# NEBRASKA = "Nebraska"
# NEW_MEXICO = "New Mexico"
# NORTH_CAROLINA = "North Carolina"
# RHODE_ISLAND = "Rhode Island"
# OHIO = "Ohio"
# OKLAHOMA = "Oklahoma"
# SOUTH_CAROLINA = "South Carolina"
# COLORADO = "Colorado"
# KANSAS = "Kansas"
# ...

# %%
dir('s')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
's'.capitalize()
# Out:
# 'S'
